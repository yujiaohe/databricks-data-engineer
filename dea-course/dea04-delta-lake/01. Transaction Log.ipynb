-- %% [markdown]
-- ## Understanding Delta Lake Transaction Log
-- Understand the cloud storage directory structure behind delta lake tables

-- %% [markdown]
-- ### 0. Create a new schema under the demo catalog for this section of the course (delta_lake)

-- %%
CREATE CATALOG IF NOT EXISTS demo
MANAGED LOCATION 'abfss://demo@deacourseextsa111.dfs.core.windows.net/';

-- %%
CREATE SCHEMA IF NOT EXISTS demo.delta_lake
MANAGED LOCATION 'abfss://demo@deacourseextsa111.dfs.core.windows.net/delta_lake';

-- %% [markdown]
-- ### 1. Create a Delta Lake Table

-- %%
CREATE TABLE IF NOT EXISTS demo.delta_lake.companies
  (
    company_name STRING,
    founded_date DATE,
    country STRING
  );

-- %%
DESCRIBE EXTENDED demo.delta_lake.companies;

-- %% [markdown]
-- ### 2. Insert some data

-- %%
INSERT INTO demo.delta_lake.companies
VALUES ("Apple", "1976-04-01", "USA");

-- %%
SELECT * FROM demo.delta_lake.companies;

-- %% [markdown]
-- ### 3. Insert some more data

-- %%
INSERT INTO demo.delta_lake.companies
VALUES ("Microsoft", "1975-04-01", "USA"),
      ("Google", "1998-08-01", "USA"),
      ("Alibaba", "1999-09-01", "China"),
      ("Tencent", "1998-11-01", "China");

-- %%
SELECT * FROM demo.delta_lake.companies;
