# %% [markdown]
# # Databricks Magic Commands
#
# - %python, %scala, %sql, %r: swithc to a different language for a specific cell
# - %md: markdown for documenting notebooks
# - %fs: run file system commands
# - %sh: run shell commands (Driver Node only)
# - %pip: install python libraries
# - %run: include/import another notebook into the current notebook (modular)

# %% [markdown]
# ## %fs: run file system commands

# %%
# %fs
ls /databricks-datasets/

# %% [markdown]
# ## %sh: run shell commands (Driver Node only)

# %%
# %sh
ps

# %% [markdown]
# ## %pip: install python libraries

# %%
# %pip list

# %%
# %pip install pandas

# %% [markdown]
# ## %run: include/import another notebook into the current notebook (modular)

# %%
# %run "/Workspace/Users/heyujiaohuhu@gmail.com/dea-course/dea02-databricks-lakehouse-platform/2.1 Environment Variables and Functions"

# %%
# %run "./2.1 Environment Variables and Functions"

# %%
env

# %%
print_env_info()
